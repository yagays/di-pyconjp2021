# %% [markdown]
# # 画像処理の導入
# ## 画像の読み込み

# %%
from PIL import Image

# %%
im = Image.open('../data/receipt01.png')

# %%
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=365x390 at 0x10B1BB730>

# %%
im.size
# Out:
# (365, 390)

# %% [markdown]
# ## Nmpyを使って画像の中身を見る

# %%
import numpy as np

# %%
np.array(im)
# Out:
# array([[[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
# ...

# %%
np.array(im).shape
# Out:
# (390, 365, 4)
